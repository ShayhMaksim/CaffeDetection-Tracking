# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
words=["TrackerTLD","MedianFlow","TrackerBoosting","TrackerKCF","TrackerCSRT","TrackerMIL"]

# %%
TrackerTLD=pd.read_csv("TrackerTLD")
TrackerMedianFlow=pd.read_csv("TrackerMedianFlow")
TrackerBoosting=pd.read_csv("TrackerBoosting")
TrackerKFC=pd.read_csv("TrackerKCF")
TrackerCSRT=pd.read_csv("TrackerCSRT")
TrackerMIL=pd.read_csv("TrackerMIL")

# %%
TrackerBoosting.columns
# Out:
# Index(['Unnamed: 0', 'C_X', 'C_Y', 'width', 'height', 'D', 'Vx', 'Vy', 'fps',
#        'try'],
#       dtype='object')

# %%
TrackerTLD0=TrackerTLD[TrackerTLD["try"]==0]
TrackerBoosting0=TrackerBoosting[TrackerBoosting["try"]==0]
TrackerCSRT0=TrackerCSRT[TrackerCSRT["try"]==0]
TrackerMIL0=TrackerMIL[TrackerMIL["try"]==0]

# %%
TrackerTLD1=TrackerTLD[TrackerTLD["try"]==1]
TrackerBoosting1=TrackerBoosting[TrackerBoosting["try"]==1]
TrackerCSRT1=TrackerCSRT[TrackerCSRT["try"]==1]
TrackerMIL1=TrackerMIL[TrackerMIL["try"]==1]

# %%
TrackerTLD2=TrackerTLD[TrackerTLD["try"]==2]
TrackerMedianFlow2=TrackerMedianFlow[TrackerMedianFlow["try"]==2]
TrackerBoosting2=TrackerBoosting[TrackerBoosting["try"]==2]
TrackerKFC2=TrackerKFC[TrackerKFC["try"]==2]
TrackerCSRT2=TrackerCSRT[TrackerCSRT["try"]==2]
TrackerMIL2=TrackerMIL[TrackerMIL["try"]==2]

# %%
TrackerTLD3=TrackerTLD[TrackerTLD["try"]==3]
TrackerMedianFlow3=TrackerMedianFlow[TrackerMedianFlow["try"]==3]
TrackerBoosting3=TrackerBoosting[TrackerBoosting["try"]==3]
TrackerKFC3=TrackerKFC[TrackerKFC["try"]==3]
TrackerCSRT3=TrackerCSRT[TrackerCSRT["try"]==3]
TrackerMIL3=TrackerMIL[TrackerMIL["try"]==3]

# %%
plt.figure(figsize=(24,12))
plt.rc('axes', labelsize=20)
plt.rc('axes',titlesize=20)
plt.rc('legend', fontsize=20)
plt.title("График положения цели") # заголовок
plt.xlabel("X, пиксель") # ось абсцисс
plt.ylabel("Y, пиксель") # ось ординат
plt.grid()      # включение отображение сетки
plt.plot(TrackerMIL['C_X'], TrackerMIL['C_Y'],'p',label="TrackerMIL")  # построение графика
plt.plot(TrackerBoosting['C_X'], TrackerBoosting['C_Y'],'p',label="TrackerBoosting")
plt.plot(TrackerTLD['C_X'], TrackerTLD['C_Y'],'p',label="TrackerTLD")
plt.plot(TrackerCSRT['C_X'], TrackerCSRT['C_Y'],'p',label="TrackerCSRT")
plt.legend(loc=0)
plt.savefig('График положения цели 0')

# %%
plt.figure(figsize=(24,12))
plt.rc('axes', labelsize=20)
plt.rc('axes',titlesize=20)
plt.rc('legend', fontsize=20)
plt.title("График положения цели") # заголовок
plt.xlabel("X, пиксель") # ось абсцисс
plt.ylabel("Y, пиксель") # ось ординат
plt.grid()      # включение отображение сетки
plt.plot(TrackerKFC['C_X'], TrackerKFC['C_Y'],'p',label="TrackerKFC")  # построение графика
plt.plot(TrackerMedianFlow['C_X'], TrackerMedianFlow['C_Y'],'p',label="TrackerMedianFlow")
plt.legend(loc=0)
plt.savefig('График положения цели 1')

# %%
plt.figure(figsize=(24,12))
plt.rc('axes', labelsize=20)
plt.rc('axes',titlesize=20)
plt.rc('legend', fontsize=20)
plt.title("График fps") # заголовок
plt.xlabel("номер кадра") # ось абсцисс
plt.ylabel("fps") # ось ординат
plt.grid()      # включение отображение сетки
plt.plot(TrackerMIL['Unnamed: 0'], TrackerMIL['fps'],label="TrackerMIL")  # построение графика
plt.plot(TrackerBoosting['Unnamed: 0'], TrackerBoosting['fps'],label="TrackerBoosting")
plt.plot(TrackerTLD['Unnamed: 0'], TrackerTLD['fps'],label="TrackerTLD")
plt.plot(TrackerKFC['Unnamed: 0'], TrackerKFC['fps'],label="TrackerKFC")  # построение графика
plt.plot(TrackerMedianFlow['Unnamed: 0'], TrackerMedianFlow['fps'],label="TrackerMedianFlow")
plt.plot(TrackerCSRT['Unnamed: 0'], TrackerCSRT['fps'],label="TrackerCSRT")
plt.legend(loc=0)
plt.savefig('График fps')

# %%
TrackerMIL_fps=np.mean(TrackerMIL['fps'])
TrackerBoosting_fps=np.mean(TrackerBoosting['fps'])
TrackerTLD_fps=np.mean(TrackerTLD['fps'])
TrackerKFC_fps=np.mean(TrackerKFC['fps'])
TrackerMedianFlow_fps=np.mean(TrackerMedianFlow['fps'])
TrackerCSRT_fps=np.mean(TrackerCSRT['fps'])

# %%
print(TrackerMIL_fps)
print(TrackerBoosting_fps)
print(TrackerTLD_fps)
print(TrackerKFC_fps)
print(TrackerMedianFlow_fps)
print(TrackerCSRT_fps)
# Out:
# 6.037799739247413
# 9.157697317273916
# 6.815641158531856
# 19.23116546296696
# 70.24502614781318
# 10.808717577199051

# %%
TrackerMIL.tail()
# Out:
#      Unnamed: 0    C_X    C_Y  width  height          D       Vx        Vy  \
# 593         593  461.5  286.5  111.0    71.0  14.690984 -0.25314  0.000000
# 594         594  459.5  288.5  111.0    71.0  14.690984 -0.50628  0.380282
# 595         595  461.5  286.5  111.0    71.0  14.690984  0.50628 -0.380282
# 596         596  461.5  286.5  111.0    71.0  14.690984  0.00000  0.000000
# 597         597  461.5  286.5  111.0    71.0  14.690984  0.00000  0.000000
#
#           fps  try
# 593  5.721727  4.0
# 594  5.629962  4.0
# 595  5.574955  4.0
# 596  5.538580  4.0
# 597  5.730384  4.0

# %%
TrackerBoosting.tail()
# Out:
#      Unnamed: 0    C_X    C_Y  width  height          D       Vx        Vy  \
# 593         593  461.5  289.5  111.0    71.0  14.690984  0.00000  0.190141
# 594         594  460.5  290.5  111.0    71.0  14.690984 -0.25314  0.190141
# 595         595  461.5  289.5  111.0    71.0  14.690984  0.25314 -0.190141
# 596         596  461.5  289.5  111.0    71.0  14.690984  0.00000  0.000000
# 597         597  461.5  290.5  111.0    71.0  14.690984  0.00000  0.190141
#
#           fps  try
# 593  8.640631  4.0
# 594  8.698624  4.0
# 595  8.589946  4.0
# 596  8.447403  4.0
# 597  8.597984  4.0

# %%
TrackerTLD.tail()
# Out:
#      Unnamed: 0         C_X         C_Y       width     height          D  \
# 593         593  432.878511  285.978100  107.947408  69.643489  15.116809
# 594         594  432.574510  287.016880  107.694775  69.480500  15.116809
# 595         595  433.509889  287.060963  107.089889  69.090251  15.116809
# 596         596  434.514223  286.236958  107.002369  69.033787  15.116809
# 597         597  434.211840  288.645120   77.137920  49.766400  20.861197
#
#            Vx        Vy       fps  try
# 593  0.089316  0.147709  6.334528  4.0
# 594 -0.079185  0.203240  6.475039  4.0
# 595  0.243645  0.008625  6.500774  4.0
# 596  0.261606 -0.161218  6.583486  4.0
# 597 -0.108694  0.650204  6.131975  4.0

# %%
TrackerKFC.tail()
# Out:
#      Unnamed: 0    C_X    C_Y  width  height          D   Vx   Vy        fps  \
# 502         502  438.5  164.0  103.0    64.0  19.266226  0.0  0.0  16.959632
# 503         503  437.5  164.0  103.0    64.0  19.266226  0.0  0.0  17.465600
# 504         504  438.5  164.0  103.0    64.0  19.266226  0.0  0.0  17.528335
# 505         505  439.5  164.0  103.0    64.0  19.266226  0.0  0.0  16.595175
# 506         506  440.5  164.0  103.0    64.0  19.266226  0.0  0.0  16.957435
#
#      try
# 502  8.0
# 503  8.0
# 504  8.0
# 505  8.0
# 506  8.0

# %%
TrackerMedianFlow.tail()
# Out:
#      Unnamed: 0         C_X         C_Y       width     height          D  \
# 556         556  289.368935  271.480530  131.562297  51.480899  23.712278
# 557         557  289.214790  272.840012  131.179678  51.331178  24.177225
# 558         558  289.818703  273.019119  131.424447  51.426958  24.177225
# 559         559  290.830162  272.082031  131.233462  51.352224  24.177225
# 560         560  290.010956  273.720200  131.618318  51.502820  23.712278
#
#       Vx   Vy        fps  try
# 556  0.0  0.0  78.225642  2.0
# 557  0.0  0.0  63.795377  2.0
# 558  0.0  0.0  71.265800  2.0
# 559  0.0  0.0  58.612967  2.0
# 560  0.0  0.0  77.792213  2.0

# %%
TrackerCSRT.tail()
# Out:
#      Unnamed: 0         C_X         C_Y       width     height          D  \
# 593         593  461.882065  289.600590  108.823456  69.607796  14.900855
# 594         594  462.144150  290.111790  108.823456  69.607796  15.116809
# 595         595  461.865524  289.924770  106.689667  68.242943  15.116809
# 596         596  462.543381  289.993923  106.689667  68.242943  15.116809
# 597         597  461.951706  290.866009  106.689667  68.242943  15.339115
#
#            Vx        Vy        fps  try
# 593 -0.063311  0.011324  11.623607  4.0
# 594  0.068267  0.100017  11.606414  4.0
# 595 -0.072576 -0.036591  11.708233  4.0
# 596  0.176566  0.013530  11.400929  4.0
# 597 -0.156384  0.173135  11.596415  4.0

# %%
plt.figure(figsize=(24,12))
plt.rc('axes', labelsize=20)
plt.rc('axes',titlesize=20)
plt.rc('legend', fontsize=20)
plt.title("График невязок положения цели по оси X 1") # заголовок
plt.xlabel("номер кадра") # ось абсцисс
plt.ylabel("X, пиксель") # ось ординат
plt.grid()      # включение отображение сетки
plt.plot(TrackerMIL0['Unnamed: 0'],TrackerCSRT0['C_X']-TrackerMIL0['C_X'],label="TrackerCSRT-TrackerMIL")  # построение графика
plt.plot(TrackerMIL0['Unnamed: 0'],TrackerCSRT0['C_X']-TrackerBoosting0['C_X'],label="TrackerCSRT-TrackerBoosting")
plt.plot(TrackerMIL0['Unnamed: 0'],TrackerCSRT0['C_X']-TrackerTLD0['C_X'],label="TrackerCSRT-TrackerTLD")
plt.legend(loc=0)
plt.savefig('График невязок положения цели по оси X 0')

# %%
plt.figure(figsize=(24,12))
plt.rc('axes', labelsize=20)
plt.rc('axes',titlesize=20)
plt.rc('legend', fontsize=20)
plt.title("График невязок положения цели по оси X 2") # заголовок
plt.xlabel("номер кадра") # ось абсцисс
plt.ylabel("X, пиксель") # ось ординат
plt.grid()      # включение отображение сетки
plt.plot(TrackerMIL1['Unnamed: 0'],TrackerCSRT1['C_X']-TrackerMIL1['C_X'],label="TrackerCSRT-TrackerMIL")  # построение графика
plt.plot(TrackerMIL1['Unnamed: 0'],TrackerCSRT1['C_X']-TrackerBoosting1['C_X'],label="TrackerCSRT-TrackerBoosting")
plt.plot(TrackerMIL1['Unnamed: 0'],TrackerCSRT1['C_X']-TrackerTLD1['C_X'],label="TrackerCSRT-TrackerTLD")
plt.legend(loc=0)
plt.savefig('График невязок положения цели по оси X 1')

# %%
plt.figure(figsize=(24,12))
plt.rc('axes', labelsize=20)
plt.rc('axes',titlesize=20)
plt.rc('legend', fontsize=20)
plt.title("График невязок положения цели по оси Y 1") # заголовок
plt.xlabel("номер кадра") # ось абсцисс
plt.ylabel("Y, пиксель") # ось ординат
plt.grid()      # включение отображение сетки
plt.plot(TrackerMIL0['Unnamed: 0'],TrackerCSRT0['C_Y']-TrackerMIL0['C_Y'],label="TrackerCSRT-TrackerMIL")  # построение графика
plt.plot(TrackerBoosting0['Unnamed: 0'],TrackerCSRT0['C_Y']-TrackerBoosting0['C_Y'],label="TrackerCSRT-TrackerBoosting")
plt.plot(TrackerTLD0['Unnamed: 0'],TrackerCSRT0['C_Y']-TrackerTLD0['C_Y'],label="TrackerCSRT-TrackerTLD")
plt.legend(loc=0)
plt.savefig('График невязок положения цели по оси Y 0')

# %%
plt.figure(figsize=(24,12))
plt.rc('axes', labelsize=20)
plt.rc('axes',titlesize=20)
plt.rc('legend', fontsize=20)
plt.title("График невязок положения цели по оси Y 2") # заголовок
plt.xlabel("номер кадра") # ось абсцисс
plt.ylabel("Y, пиксель") # ось ординат
plt.grid()      # включение отображение сетки
plt.plot(TrackerMIL1['Unnamed: 0'],TrackerCSRT1['C_Y']-TrackerMIL1['C_Y'],label="TrackerCSRT-TrackerMIL")  # построение графика
plt.plot(TrackerBoosting1['Unnamed: 0'],TrackerCSRT1['C_Y']-TrackerBoosting1['C_Y'],label="TrackerCSRT-TrackerBoosting")
plt.plot(TrackerTLD1['Unnamed: 0'],TrackerCSRT1['C_Y']-TrackerTLD1['C_Y'],label="TrackerCSRT-TrackerTLD")
plt.legend(loc=0)
plt.savefig('График невязок положения цели по оси Y 1')

# %%
plt.figure(figsize=(24,12))
plt.rc('axes', labelsize=20)
plt.rc('axes',titlesize=20)
plt.rc('legend', fontsize=20)
plt.title("График невязок положения цели по оси Y 4") # заголовок
plt.xlabel("номер кадра") # ось абсцисс
plt.ylabel("Y, пиксель") # ось ординат
plt.grid()      # включение отображение сетки
plt.plot(TrackerMIL3['Unnamed: 0'],TrackerCSRT3['C_Y']-TrackerMIL3['C_Y'],label="TrackerCSRT-TrackerMIL")  # построение графика
plt.plot(TrackerBoosting3['Unnamed: 0'],TrackerCSRT3['C_Y']-TrackerBoosting3['C_Y'],label="TrackerCSRT-TrackerBoosting")
plt.plot(TrackerTLD3['Unnamed: 0'],TrackerCSRT3['C_Y']-TrackerTLD3['C_Y'],label="TrackerCSRT-TrackerTLD")
plt.legend(loc=0)
plt.savefig('График невязок положения цели по оси Y 3')

# %%
plt.figure(figsize=(24,12))
plt.rc('axes', labelsize=20)
plt.rc('axes',titlesize=20)
plt.rc('legend', fontsize=20)
plt.title("График невязок положения цели по оси X 4") # заголовок
plt.xlabel("номер кадра") # ось абсцисс
plt.ylabel("X, пиксель") # ось ординат
plt.grid()      # включение отображение сетки
plt.plot(TrackerMIL3['Unnamed: 0'],TrackerCSRT3['C_X']-TrackerMIL3['C_X'],label="TrackerCSRT-TrackerMIL")  # построение графика
plt.plot(TrackerBoosting3['Unnamed: 0'],TrackerCSRT3['C_X']-TrackerBoosting3['C_X'],label="TrackerCSRT-TrackerBoosting")
plt.plot(TrackerTLD3['Unnamed: 0'],TrackerCSRT3['C_X']-TrackerTLD3['C_X'],label="TrackerCSRT-TrackerTLD")
plt.legend(loc=0)
plt.savefig('График невязок положения цели по оси X 3')
